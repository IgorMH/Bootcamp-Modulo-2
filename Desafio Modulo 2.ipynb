# %%
import pandas as pd
import numpy as np
#pd.options.display.max_rows = 300

# %%
class Tratamento:
    def __init__(self):
        self.usuarios = pd.read_csv("Dados/users.csv")
        self.precos = pd.read_csv("Dados/prices.csv")
        self.velocidade = pd.read_csv("Dados/avgspeed.csv")

# %%
def unifica_dados(self):
    self.dados_unificados = self.precos.set_index("Name").join(self.usuarios.set_index("Country or area")).join(self.velocidade.set_index("Country"))
    #df = pd.merge(self.usuarios, self.precos, how = 'outer', on = 'Pais')
    #self.dados_unificados = pd.merge(df, self.velocidade, how = 'outer', on = 'Pais')
    return self.dados_unificados

# %%
teste = Tratamento()

# %%
unifica_dados(teste)
# Out:
#                Country code    Continental region  NO. OF Internet Plans   \
# Afghanistan              AF  ASIA (EX. NEAR EAST)                    35.0
# Albania                  AL        EASTERN EUROPE                    32.0
# Algeria                  DZ       NORTHERN AFRICA                    20.0
# American Samoa           AS               OCEANIA                    11.0
# Andorra                  AD        WESTERN EUROPE                     7.0
# ...                     ...                   ...                     ...
# Western Sahara           EH       NORTHERN AFRICA                    25.0
# Yemen                    YE             NEAR EAST                    17.0
# Zambia                   ZM    SUB-SAHARAN AFRICA                    60.0
# Zimbabwe                 ZW    SUB-SAHARAN AFRICA                     NaN
# Åland Islands            AX        WESTERN EUROPE                     7.0
#
#                Average price of 1GB (USD) Cheapest 1GB for 30 days (USD)  \
# Afghanistan                         $1.02                          $0.38
# Albania                             $2.80                          $0.72
# Algeria                             $0.51                          $0.16
# American Samoa                      $2.00                          $1.33
# Andorra                             $7.49                          $1.06
# ...                                   ...                            ...
# Western Sahara                      $0.88                          $0.44
# Yemen                              $15.98                          $0.40
# Zambia                              $1.13                          $0.01
# Zimbabwe        UNRELIABLE EXCHANGE RATES                            NaN
# Åland Islands                       $2.75                          $2.35
#
#                Most expensive 1GB (USD)  \
# Afghanistan                       $2.12
# Albania                          $96.39
# Algeria                           $2.24
# American Samoa                    $2.92
# Andorra                          $65.07
# ...                                 ...
# Western Sahara                    $5.50
# Yemen                            $39.94
# Zambia                            $6.80
# Zimbabwe                            NaN
# Åland Islands                     $8.81
#
#                Average price of 1GB (USD  at the start of 2021)  \
# Afghanistan                                               $1.55
# Albania                                                   $2.83
# Algeria                                                   $0.65
# American Samoa                                            $2.50
# Andorra                                                   $9.54
# ...                                                         ...
# Western Sahara                                            $0.99
# Yemen                                                    $15.98
# Zambia                                                    $1.36
# Zimbabwe                                                    NaN
# Åland Islands                                             $3.24
#
#                Average price of 1GB (USD – at start of 2020)        Subregion  \
# Afghanistan                                            $1.60    Southern Asia
# Albania                                                $5.28  Southern Europe
# Algeria                                                $5.15  Northern Africa
# American Samoa                                         $1.94              NaN
# Andorra                                               $12.58  Southern Europe
# ...                                                      ...              ...
# Western Sahara                                         $1.18              NaN
# Yemen                                                 $15.73     Western Asia
# Zambia                                                 $2.25   Eastern Africa
# Zimbabwe                                                 NaN   Eastern Africa
# Åland Islands                                          $4.64              NaN
#
#                 Region Internet users  Population  Avg \n(Mbit/s)Ookla
# Afghanistan       Asia      4,068,194  37,171,921                 5.50
# Albania         Europe      2,105,339   2,882,740                40.48
# Algeria         Africa     26,350,000  42,228,408                12.44
# American Samoa     NaN            NaN         NaN                  NaN
# Andorra         Europe         76,095      77,006                  NaN
# ...                ...            ...         ...                  ...
# Western Sahara     NaN            NaN         NaN                  NaN
# Yemen             Asia      7,548,512  28,498,683                16.89
# Zambia          Africa      4,760,715  17,351,708                10.36
# Zimbabwe        Africa      4,472,992  14,438,802                13.99
# Åland Islands      NaN            NaN         NaN                  NaN
#
# [243 rows x 13 columns]

# %%
def tratamento_dados(self):
    unifica_dados(self)
    self.dados_unificados = self.dados_unificados.dropna(subset=["Population"])

    self.dados_unificados["Internet users"] = self.dados_unificados["Internet users"].str.replace(",", "").apply(pd.to_numeric, errors="coerce")

    self.dados_unificados["Population"] = self.dados_unificados["Population"].str.replace(",", "").apply(pd.to_numeric, errors="coerce")

    self.dados_unificados["Average price of 1GB (USD)"] = self.dados_unificados["Average price of 1GB (USD)"].str.replace("$", "", regex=False).apply(pd.to_numeric, errors="coerce")

    self.dados_unificados["Cheapest 1GB for 30 days (USD)"] = self.dados_unificados["Cheapest 1GB for 30 days (USD)"].str.replace("$", "", regex=False).apply(pd.to_numeric, errors="coerce")

    self.dados_unificados["Most expensive 1GB (USD)"] = self.dados_unificados["Most expensive 1GB (USD)"].str.replace("$", "", regex=False).apply(pd.to_numeric, errors="coerce")

    self.dados_unificados["Average price of 1GB (USD  at the start of 2021)"] = self.dados_unificados["Average price of 1GB (USD  at the start of 2021)"].str.replace("$", "", regex=False).apply(pd.to_numeric, errors="coerce")

    self.dados_unificados["Average price of 1GB (USD – at start of 2020)"] = self.dados_unificados["Average price of 1GB (USD – at start of 2020)"].str.replace("$", "", regex=False).apply(pd.to_numeric, errors="coerce")

    self.dados_unificados = self.dados_unificados.dropna(subset=["Average price of 1GB (USD)"])
    self.dados_unificados = self.dados_unificados.dropna(subset=["Cheapest 1GB for 30 days (USD)"])
    self.dados_unificados = self.dados_unificados.dropna(subset=["Most expensive 1GB (USD)"])
    self.dados_unificados = self.dados_unificados.dropna(subset=["Average price of 1GB (USD  at the start of 2021)"])
    self.dados_unificados = self.dados_unificados.dropna(subset=["Average price of 1GB (USD – at start of 2020)"])
    
    #occur = self.dados_unificados[self.dados_unificados["Avg \n(Mbit/s)Ookla"]].isna()
    #occur2 = occur.groupby(['Region']).size()
    return self.dados_unificados

# %%
teste = Tratamento()

# %%
tratamento_dados(teste)
# Out:
#             Country code    Continental region  NO. OF Internet Plans   \
# Afghanistan           AF  ASIA (EX. NEAR EAST)                    35.0
# Albania               AL        EASTERN EUROPE                    32.0
# Algeria               DZ       NORTHERN AFRICA                    20.0
# Andorra               AD        WESTERN EUROPE                     7.0
# Angola                AO    SUB-SAHARAN AFRICA                    20.0
# ...                  ...                   ...                     ...
# Uruguay               UY         SOUTH AMERICA                    35.0
# Uzbekistan            UZ     CIS (FORMER USSR)                    60.0
# Vietnam               VN  ASIA (EX. NEAR EAST)                    46.0
# Yemen                 YE             NEAR EAST                    17.0
# Zambia                ZM    SUB-SAHARAN AFRICA                    60.0
#
#              Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Afghanistan                        1.02                            0.38
# Albania                            2.80                            0.72
# Algeria                            0.51                            0.16
# Andorra                            7.49                            1.06
# Angola                             1.61                            1.03
# ...                                 ...                             ...
# Uruguay                            1.51                            0.10
# Uzbekistan                         0.60                            0.01
# Vietnam                            0.49                            0.07
# Yemen                             15.98                            0.40
# Zambia                             1.13                            0.01
#
#              Most expensive 1GB (USD)  \
# Afghanistan                      2.12
# Albania                         96.39
# Algeria                          2.24
# Andorra                         65.07
# Angola                           3.21
# ...                               ...
# Uruguay                          6.33
# Uzbekistan                      23.75
# Vietnam                          5.55
# Yemen                           39.94
# Zambia                           6.80
#
#              Average price of 1GB (USD  at the start of 2021)  \
# Afghanistan                                              1.55
# Albania                                                  2.83
# Algeria                                                  0.65
# Andorra                                                  9.54
# Angola                                                   5.29
# ...                                                       ...
# Uruguay                                                  1.58
# Uzbekistan                                               1.34
# Vietnam                                                  0.57
# Yemen                                                   15.98
# Zambia                                                   1.36
#
#              Average price of 1GB (USD – at start of 2020)  \
# Afghanistan                                           1.60
# Albania                                               5.28
# Algeria                                               5.15
# Andorra                                              12.58
# Angola                                                7.95
# ...                                                    ...
# Uruguay                                               2.80
# Uzbekistan                                            3.27
# Vietnam                                               1.31
# Yemen                                                15.73
# Zambia                                                2.25
#
#                       Subregion    Region  Internet users  Population  \
# Afghanistan       Southern Asia      Asia         4068194    37171921
# Albania         Southern Europe    Europe         2105339     2882740
# Algeria         Northern Africa    Africa        26350000    42228408
# Andorra         Southern Europe    Europe           76095       77006
# Angola            Middle Africa    Africa         4271053    30809787
# ...                         ...       ...             ...         ...
# Uruguay           South America  Americas         2360269     3449285
# Uzbekistan         Central Asia      Asia        16692456    32476244
# Vietnam      South-eastern Asia      Asia        68172134    95545962
# Yemen              Western Asia      Asia         7548512    28498683
# Zambia           Eastern Africa    Africa         4760715    17351708
#
#              Avg \n(Mbit/s)Ookla
# Afghanistan                 5.50
# Albania                    40.48
# Algeria                    12.44
# Andorra                      NaN
# Angola                     22.59
# ...                          ...
# Uruguay                    34.43
# Uzbekistan                 13.27
# Vietnam                    33.90
# Yemen                      16.89
# Zambia                     10.36
#
# [188 rows x 13 columns]

# %%
def analise_planos(self):
    tratamento_dados(self)
    mediana = self.dados_unificados["NO. OF Internet Plans "].median()
    self.dados_unificados["AnaliseQuantidadePlanos"] = self.dados_unificados.apply(lambda row: "Muito" if row["NO. OF Internet Plans "] >= mediana else "Pouco", axis=1)
    # self.dados_unificados["AnaliseQuantidadePlanos"] = np.select(
    #     [
    #     self.dados_unificados["NO. OF Internet Plans "] >= mediana, 
    #     self.dados_unificados["NO. OF Internet Plans "] < mediana,
    #     ],
    #     [
    #     "Maior", "Menor"
    #     ]
    # )
    #occur = self.dados_unificados.groupby(['AnaliseQuantidadePlanos']).size()
    return self.dados_unificados

# %%
def analise_preco(self):
    analise_planos(self)
    mediana = self.dados_unificados["Average price of 1GB (USD)"].median()
    self.dados_unificados["AnalisePrecoMedio"] = self.dados_unificados.apply(lambda row: "Caro" if row["Average price of 1GB (USD)"] >= mediana else "Barato", axis=1)
    # self.dados_unificados["AnaliseQuantidadePlanos"] = np.select(
    #     [
    #     self.dados_unificados["NO. OF Internet Plans "] >= mediana, 
    #     self.dados_unificados["NO. OF Internet Plans "] < mediana,
    #     ],
    #     [
    #     "Maior", "Menor"
    #     ]
    # )
    #occur = self.dados_unificados.groupby(['AnalisePrecoMedio']).size()
    return self.dados_unificados

# %%
def plano_preco(self):
    analise_preco(self)
    self.dados_unificados["PerfilPlanoPreco"] = self.dados_unificados.apply(lambda row: row["AnaliseQuantidadePlanos"] + row["AnalisePrecoMedio"], axis=1)
    occur = self.dados_unificados.groupby('PerfilPlanoPreco').mean()
    return occur

# %%
teste = Tratamento()

# %%
plano_preco(teste)
# Out:
#                   NO. OF Internet Plans   Average price of 1GB (USD)  \
# PerfilPlanoPreco
# MuitoBarato                    44.913793                    0.965517
# MuitoCaro                      39.388889                    4.580000
# PoucoBarato                    16.542857                    1.131429
# PoucoCaro                      14.796610                    7.877797
#
#                   Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# PerfilPlanoPreco
# MuitoBarato                             0.225517                 16.791897
# MuitoCaro                               1.015833                 38.326667
# PoucoBarato                             0.439714                 13.394000
# PoucoCaro                               3.619661                 49.931864
#
#                   Average price of 1GB (USD  at the start of 2021)  \
# PerfilPlanoPreco
# MuitoBarato                                               1.457069
# MuitoCaro                                                 5.939167
# PoucoBarato                                               2.193429
# PoucoCaro                                                 8.945763
#
#                   Average price of 1GB (USD – at start of 2020)  \
# PerfilPlanoPreco
# MuitoBarato                                            4.888621
# MuitoCaro                                              9.246667
# PoucoBarato                                            5.515143
# PoucoCaro                                             11.964237
#
#                   Internet users    Population  Avg \n(Mbit/s)Ookla
# PerfilPlanoPreco
# MuitoBarato         6.172513e+07  9.261861e+07            33.583333
# MuitoCaro           2.330406e+07  3.116462e+07            44.002727
# PoucoBarato         6.081918e+06  1.368834e+07            25.371852
# PoucoCaro           2.432514e+06  5.106056e+06            48.781538

# %%
def real_dolar(self):
    plano_preco(self)
    #self.dados_unificados["Most expensive 1GB (USD)"] = self.dados_unificados.apply(lambda row: (row["Most expensive 1GB (USD)"])*5)
    self.dados_unificados[["Average price of 1GB (USD)"]] = self.dados_unificados[["Average price of 1GB (USD)"]].apply(lambda x: x*5)
    self.dados_unificados[["Cheapest 1GB for 30 days (USD)"]] = self.dados_unificados[["Cheapest 1GB for 30 days (USD)"]].apply(lambda x: x*5)
    self.dados_unificados[["Most expensive 1GB (USD)"]] = self.dados_unificados[["Most expensive 1GB (USD)"]].apply(lambda x: x*5)
    self.dados_unificados[["Average price of 1GB (USD  at the start of 2021)"]] = self.dados_unificados[["Average price of 1GB (USD  at the start of 2021)"]].apply(lambda x: x*5)
    self.dados_unificados[["Average price of 1GB (USD – at start of 2020)"]] = self.dados_unificados[["Average price of 1GB (USD – at start of 2020)"]].apply(lambda x: x*5)
    return self.dados_unificados

# %%
teste = Tratamento()

# %%
real_dolar(teste)
# Out:
#             Country code    Continental region  NO. OF Internet Plans   \
# Afghanistan           AF  ASIA (EX. NEAR EAST)                    35.0
# Albania               AL        EASTERN EUROPE                    32.0
# Algeria               DZ       NORTHERN AFRICA                    20.0
# Andorra               AD        WESTERN EUROPE                     7.0
# Angola                AO    SUB-SAHARAN AFRICA                    20.0
# ...                  ...                   ...                     ...
# Uruguay               UY         SOUTH AMERICA                    35.0
# Uzbekistan            UZ     CIS (FORMER USSR)                    60.0
# Vietnam               VN  ASIA (EX. NEAR EAST)                    46.0
# Yemen                 YE             NEAR EAST                    17.0
# Zambia                ZM    SUB-SAHARAN AFRICA                    60.0
#
#              Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# Afghanistan                        5.10                            1.90
# Albania                           14.00                            3.60
# Algeria                            2.55                            0.80
# Andorra                           37.45                            5.30
# Angola                             8.05                            5.15
# ...                                 ...                             ...
# Uruguay                            7.55                            0.50
# Uzbekistan                         3.00                            0.05
# Vietnam                            2.45                            0.35
# Yemen                             79.90                            2.00
# Zambia                             5.65                            0.05
#
#              Most expensive 1GB (USD)  \
# Afghanistan                     10.60
# Albania                        481.95
# Algeria                         11.20
# Andorra                        325.35
# Angola                          16.05
# ...                               ...
# Uruguay                         31.65
# Uzbekistan                     118.75
# Vietnam                         27.75
# Yemen                          199.70
# Zambia                          34.00
#
#              Average price of 1GB (USD  at the start of 2021)  \
# Afghanistan                                              7.75
# Albania                                                 14.15
# Algeria                                                  3.25
# Andorra                                                 47.70
# Angola                                                  26.45
# ...                                                       ...
# Uruguay                                                  7.90
# Uzbekistan                                               6.70
# Vietnam                                                  2.85
# Yemen                                                   79.90
# Zambia                                                   6.80
#
#              Average price of 1GB (USD – at start of 2020)  \
# Afghanistan                                           8.00
# Albania                                              26.40
# Algeria                                              25.75
# Andorra                                              62.90
# Angola                                               39.75
# ...                                                    ...
# Uruguay                                              14.00
# Uzbekistan                                           16.35
# Vietnam                                               6.55
# Yemen                                                78.65
# Zambia                                               11.25
#
#                       Subregion    Region  Internet users  Population  \
# Afghanistan       Southern Asia      Asia         4068194    37171921
# Albania         Southern Europe    Europe         2105339     2882740
# Algeria         Northern Africa    Africa        26350000    42228408
# Andorra         Southern Europe    Europe           76095       77006
# Angola            Middle Africa    Africa         4271053    30809787
# ...                         ...       ...             ...         ...
# Uruguay           South America  Americas         2360269     3449285
# Uzbekistan         Central Asia      Asia        16692456    32476244
# Vietnam      South-eastern Asia      Asia        68172134    95545962
# Yemen              Western Asia      Asia         7548512    28498683
# Zambia           Eastern Africa    Africa         4760715    17351708
#
#              Avg \n(Mbit/s)Ookla AnaliseQuantidadePlanos AnalisePrecoMedio  \
# Afghanistan                 5.50                   Muito            Barato
# Albania                    40.48                   Muito              Caro
# Algeria                    12.44                   Pouco            Barato
# Andorra                      NaN                   Pouco              Caro
# Angola                     22.59                   Pouco            Barato
# ...                          ...                     ...               ...
# Uruguay                    34.43                   Muito            Barato
# Uzbekistan                 13.27                   Muito            Barato
# Vietnam                    33.90                   Muito            Barato
# Yemen                      16.89                   Pouco              Caro
# Zambia                     10.36                   Muito            Barato
#
#             PerfilPlanoPreco
# Afghanistan      MuitoBarato
# Albania            MuitoCaro
# Algeria          PoucoBarato
# Andorra            PoucoCaro
# Angola           PoucoBarato
# ...                      ...
# Uruguay          MuitoBarato
# Uzbekistan       MuitoBarato
# Vietnam          MuitoBarato
# Yemen              PoucoCaro
# Zambia           MuitoBarato
#
# [188 rows x 16 columns]

# %%
def renomeia(self):
    real_dolar(self)
    self.dados_unificados = self.dados_unificados.rename(
      columns = {'': 'Pais',
                 'Country code': 'Codigo',
                 'Continental region': 'Regiao Continental',
                 'NO. OF Internet Plans ': 'Numero de Planos',
                 'Average price of 1GB (USD)': 'Preco medio de 1GB',
                 'Cheapest 1GB for 30 days (USD)': '1GB mais barato',
                 'Most expensive 1GB (USD)': '1GB mais caro',
                 'Average price of 1GB (USD  at the start of 2021)': 'Preco medio de 1GB desde 2021',
                 'Average price of 1GB (USD – at start of 2020)': 'Preco medio de 1GB desde 2020',
                 'Subregion': 'Subcontinente',
                 'Region': 'Continente',
                 'Internet users': 'Numero de Usuarios',
                 'Population': 'Populacao',
                 'Avg \n(Mbit/s)Ookla': 'Velocidade media',
                 'AnaliseQuantidadePlanos': 'Numero de Plano Qualitativo',
                 'AnalisePrecoMedio': 'Preco medio de 1GB Qualitativo',
                 'PerfilPlanoPreco': 'Perfil de Plano e Preco'}
    )
    #occur = self.dados_unificados.groupby(['Preco medio de 1GB Qualitativo']).size()
    return self.dados_unificados

# %%
teste = Tratamento()

# %%
renomeia(teste)
# Out:
#             Codigo    Regiao Continental  Numero de Planos  \
# Afghanistan     AF  ASIA (EX. NEAR EAST)              35.0
# Albania         AL        EASTERN EUROPE              32.0
# Algeria         DZ       NORTHERN AFRICA              20.0
# Andorra         AD        WESTERN EUROPE               7.0
# Angola          AO    SUB-SAHARAN AFRICA              20.0
# ...            ...                   ...               ...
# Uruguay         UY         SOUTH AMERICA              35.0
# Uzbekistan      UZ     CIS (FORMER USSR)              60.0
# Vietnam         VN  ASIA (EX. NEAR EAST)              46.0
# Yemen           YE             NEAR EAST              17.0
# Zambia          ZM    SUB-SAHARAN AFRICA              60.0
#
#              Preco medio de 1GB  1GB mais barato  1GB mais caro  \
# Afghanistan                5.10             1.90          10.60
# Albania                   14.00             3.60         481.95
# Algeria                    2.55             0.80          11.20
# Andorra                   37.45             5.30         325.35
# Angola                     8.05             5.15          16.05
# ...                         ...              ...            ...
# Uruguay                    7.55             0.50          31.65
# Uzbekistan                 3.00             0.05         118.75
# Vietnam                    2.45             0.35          27.75
# Yemen                     79.90             2.00         199.70
# Zambia                     5.65             0.05          34.00
#
#              Preco medio de 1GB desde 2021  Preco medio de 1GB desde 2020  \
# Afghanistan                           7.75                           8.00
# Albania                              14.15                          26.40
# Algeria                               3.25                          25.75
# Andorra                              47.70                          62.90
# Angola                               26.45                          39.75
# ...                                    ...                            ...
# Uruguay                               7.90                          14.00
# Uzbekistan                            6.70                          16.35
# Vietnam                               2.85                           6.55
# Yemen                                79.90                          78.65
# Zambia                                6.80                          11.25
#
#                   Subcontinente Continente  Numero de Usuarios  Populacao  \
# Afghanistan       Southern Asia       Asia             4068194   37171921
# Albania         Southern Europe     Europe             2105339    2882740
# Algeria         Northern Africa     Africa            26350000   42228408
# Andorra         Southern Europe     Europe               76095      77006
# Angola            Middle Africa     Africa             4271053   30809787
# ...                         ...        ...                 ...        ...
# Uruguay           South America   Americas             2360269    3449285
# Uzbekistan         Central Asia       Asia            16692456   32476244
# Vietnam      South-eastern Asia       Asia            68172134   95545962
# Yemen              Western Asia       Asia             7548512   28498683
# Zambia           Eastern Africa     Africa             4760715   17351708
#
#              Velocidade media Numero de Plano Qualitativo  \
# Afghanistan              5.50                       Muito
# Albania                 40.48                       Muito
# Algeria                 12.44                       Pouco
# Andorra                   NaN                       Pouco
# Angola                  22.59                       Pouco
# ...                       ...                         ...
# Uruguay                 34.43                       Muito
# Uzbekistan              13.27                       Muito
# Vietnam                 33.90                       Muito
# Yemen                   16.89                       Pouco
# Zambia                  10.36                       Muito
#
#             Preco medio de 1GB Qualitativo Perfil de Plano e Preco
# Afghanistan                         Barato             MuitoBarato
# Albania                               Caro               MuitoCaro
# Algeria                             Barato             PoucoBarato
# Andorra                               Caro               PoucoCaro
# Angola                              Barato             PoucoBarato
# ...                                    ...                     ...
# Uruguay                             Barato             MuitoBarato
# Uzbekistan                          Barato             MuitoBarato
# Vietnam                             Barato             MuitoBarato
# Yemen                                 Caro               PoucoCaro
# Zambia                              Barato             MuitoBarato
#
# [188 rows x 16 columns]

# %%
def salva(self):
    renomeia(self)
    self.dados_unificados.to_csv('Dados/dados_unificado.csv')
    self.dados_unificados.to_pickle('Dados/dados_unificado2.pkl')
    self.dados_unificados.to_pickle('Dados/dados_unificado3.gz')

# %%
teste = Tratamento()

# %%
salva(teste)
